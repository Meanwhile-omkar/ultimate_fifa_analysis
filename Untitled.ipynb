# %%
import matplotlib.pyplot as plt
brands = ["oneplus","motorola","iphone","macromax","vivo/oppo"]
x=[111,50,200,20,150]
ex=[0.1,0.1,0.1,0.2,0.1]
plt.pie(x,labels = brands,explode=ex,shadow=True,)
plt.show()
